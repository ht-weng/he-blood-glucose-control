# %%
import csv, math
from math import exp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def write_to_csv(ls, filename):
    df = pd.DataFrame(ls)
    df.to_csv(filename, index=None, header=None)

# %%
"""
    The PID controller from Steil et al 2011, The effect of insulin feedback on closed loop glucose control
    K_P = I_DIR/135. I_DIR: daily insulin requirement (unit/kg). I_DIR = 0.55 * weight(kg)
    K_P = 0.55*70/135 = 0.28518519
    T_D is 450 min on day time and 150 min at night.
    T_I is 90 min on daytime and 60 min at night.
    Glucose target is 90 mg/dl (5 mmol/L) on daytime and 110 mg/dl (6.11 mmol/L) at night.
    1 mmol/L = 18 mg/dl.
    The patient is 70kg in this simulation.
    U(t) - mU/min
    
    if day_flag:
        T_I = 450 -> K_P_T_I = K_P / T_I = 0.00063374
        T_D = 90 -> K_P_T_D = K_P / T_D = 0.00316872
        G_target = 5
    else:
        T_I = 150 -> K_P_T_I = K_P / T_I = 0.00190123
        T_D = 60 -> K_P_T_D = K_P / T_D = 0.00475309
        G_target = 6.11
"""
# Gs is the tuple of G(t-1) and G(t)
def pid_controller(Gs, I_t_1, day_flag):
    
    # Parameters
    K_P = 0.28518519
    if day_flag:
        K_P_T_I = 0.00063374
        K_P_T_D = 0.00316872
        G_target = 5
    else:
        K_P_T_I = 0.00190123
        K_P_T_D = 0.00475309
        G_target = 6.11
    # Calculate errors between the actual and target glucose levels.
    error_1 = Gs[1] - G_target
    error_2 = Gs[0] - G_target
    
    # Calculate U(t) using PID based on errors
    I_t = K_P_T_I * error_1 + I_t_1
    U_t = K_P * error_1 + I_t + K_P_T_D * (error_1 - error_2)
    
    if U_t < 0:
        # Remove negative U(t)
        U_t=0
    else:
        # Scale U_t from U/h to mU/min
        # U_t = (1000/60) * U_t = 16.67 * U_t
        U_t = 16.67 * U_t
    
    return U_t, I_t

# %%
"""
    Human Glucose - Insulin System Model by Bergman 1981
    A simple 3 equation model.

    States = 
        [Plasma Glucose(G), 
        Plasma Insulin Remote Compartment(X), 
        Plasma Insulin(I)]

    From the paper Furler et al, 1985. Blood Glucose Control by Intermittent Loop Closure in the Basal Mode: 
        Computer Simulation Studies with a Diabetic Model
    
    The patient weighs 70kg.
    G(t) - mmol/L
    X(t) - mU/L
    I(t) - mU/L
    U(t) - mU/min
    D(t) - mmol/L
    V_I = 12L
    n = 0.09 min^-1
    G_b = 4.5 mmol/L
    I_b = 15 mU/L
    X_b = 15 mU/L
    P_1 = -0.028 min^-1
    P_2 = -0.025 min^-1
    P_3 = 0.000005 min^-2 mU^-1 L
"""
def bergman_minmod(y, U, D):
    
    # Get the last G(t), X(t) and I(t)
    G=y[-1, 0]
    X=y[-1, 1]
    I=y[-1, 2]
    
    # Parameters
    G_b = 4.5
    X_b = 15
    I_b = 15
    P_1 = -0.028
    P_2 = -0.025
    P_3 = 0.000005
    V_I = 12
    n = 0.09
    
    # Minimal Model
    Gdt = P_1 * (G - G_b) - (X - X_b) * G + D
    Xdt = P_2 * (X - X_b) + P_3 * (I - I_b)
    Idt = -n * I + U / V_I
    
    dy_dt = [Gdt, Xdt, Idt]
    return dy_dt

# %%
def meal_profile(t):
    if t >= 100 and t < 300:
        m = 0.5 * exp(-0.05 * (t-100))
    elif t >= 400 and t < 600:
        m = 1.157 * exp(-0.05 * (t-400))
    elif t >= 700 and t < 900:
        m = 1.816 * exp(-0.05 * (t-700))
    elif t >= 1800 and t < 2000:
        m = 0.6 * exp(-0.05 * (t-1800))
    elif t >= 2100 and t < 2300:
        m = 1.257 * exp(-0.05 * (t-2100))
    elif t >= 2400 and t < 2600:
        m = 1.6 * exp(-0.05 * (t-2400))
    else:
        m = 0
    return m

# %%
def get_column(x, index):
    result = []
    for i in range(len(x)):
        result.append(x[i][index])
    return result

# %%
tend = 5000
tspan = [i for i in range(tend)]

# Set up initial conditions
y0 = y1 = [4.5, 15, 15]
y = np.array([y0, y1])

# Meal profiles
D = []
for t in tspan:
    D.append(meal_profile(t))

U = []
    
# Simulation
I_t_1 = 0
for t in tspan:
    # Determine whether it is day
    if (t % 1800 <= 900):
        day_flag = True
    else:
        day_flag = False
    
    # Init
    G_t_1 = y[-1][0]
    G_t_2 = y[-2][0]
    Gs = [G_t_2, G_t_1]
    
    # Calculate insulin infusion signal
    U_t, I_t = pid_controller(Gs, I_t_1, day_flag)
    
    I_t_1 = I_t
    U.append(U_t)
    
    # Calculate bergman model response
    dy_dt = bergman_minmod(y, U_t, D[t])
    
    # y(t) = y(t-1) + dy/dt
    yt = y[-1] + dy_dt
    
    # Append yt to y
    y = np.vstack([y, yt])
    
# Display the list of G(t), X(t) and I(t)
y
# Out:
# array([[4.50000000e+00, 1.50000000e+01, 1.50000000e+01],
#        [4.50000000e+00, 1.50000000e+01, 1.50000000e+01],
#        [4.50000000e+00, 1.50000000e+01, 1.36500000e+01],
#        ...,
#        [5.04000000e+00, 1.49970000e+01, 1.14310811e-92],
#        [5.04000000e+00, 1.49970000e+01, 1.04022838e-92],
#        [5.04000000e+00, 1.49970000e+01, 9.46607822e-93]])

# %%
# Ignore the initial conditions
y = y[2:]
# Select G(t), X(t) and I(t)
G = get_column(y, 0)
X = get_column(y, 1)
I = get_column(y, 2)

# Set the thresholds
glucose_high = 8.3
glucose_low = 3.9

# %%
# Visulisation
plt.figure(figsize=(20, 30))
plt.subplot(5,1,1)
plt.plot(tspan, D, linestyle = ':', label='Meal Profile')
plt.legend()
plt.xlabel('Time (min)')
plt.ylabel('mmol/L')
plt.title('Meal Profile')

plt.subplot(5,1,2)
plt.plot(tspan,G, linestyle = ':', label='Blood Glucose Concentration')
plt.axhline(y = glucose_low, color = 'r', linestyle = ':', label='Low Glucose Threshold')
plt.axhline(y = glucose_high, color = 'y', linestyle = ':', label='High Glucose Threshold')
plt.legend()
plt.xlabel('Time (min)')
plt.ylabel('mmol/L')
plt.title('Blood Glucose Level')

plt.subplot(5,1,3)
plt.plot(tspan, U, linestyle = ':', label='Insulin Infusion Signal')
plt.legend()
plt.xlabel('Time (min)')
plt.ylabel('mU/min')
plt.title('Insulin Infusion Rate')

plt.subplot(5,1,4)
plt.plot(tspan, I, linestyle = ':', label='Blood Insulin Concentration')
plt.legend()
plt.xlabel('Time (min)')
plt.ylabel('mU/L')
plt.title('Plasma Insulin')

plt.subplot(5,1,5)
plt.plot(tspan, X, linestyle = ':', label='The Effect of Active Insulin')
plt.legend()
plt.xlabel('Time (min)')
plt.ylabel('mU/L')
plt.title('Remote Compartment Insulin')

plt.show()

# %%
# write_to_csv(G, '../data/pid_bergman_plaintext_G.csv')
# write_to_csv(X, '../data/pid_bergman_plaintext_X.csv')
# write_to_csv(I, '../data/pid_bergman_plaintext_I.csv')
# write_to_csv(U, '../data/pid_bergman_plaintext_U.csv')
# write_to_csv(D, '../data/meal_profile_1.csv')
